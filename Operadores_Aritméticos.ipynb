# %%
#1
valorPago = 345/7;
attValorPago = round(valorPago,2);
print('Cada amigo pagou: R$',attValorPago);
# Out:
# Cada amigo pagou: R$ 49.29

# %%
#2
nVans = 47//10;
print("Sairam lotadas:", nVans,'vans')
# Out:
# Sairam lotadas: 4 vans

# %%
#3
nVans = 47//10;
vagasVans = nVans*10;
alunosRestantes = 47-vagasVans;
print('Sobraram:', alunosRestantes, 'alunos')
# Out:
# Sobraram: 7 alunos

# %%
47%10
# Out:
# 7

# %%
#4
lucroBruto = 150*40;
lucroLiquido = lucroBruto-3500;
print('O lucro liquido deles foi de: R$', lucroLiquido);
# Out:
# O lucro liquido deles foi de: R$ 2500

# %%
#5
manha = 120;
tarde = 85;
noite = tarde*3;
totalPecorrido = manha+tarde+noite;
print('O total percorrido foi de:', totalPecorrido, 'km');
# Out:
# O total percorrido foi de: 460 km

# %%
#6
alturaLimite = 140;
alturaVisitante = 140;
vrfcAltura = alturaVisitante >= alturaLimite
if vrfcAltura==True:
  print('Altura Aceita');
else:
  print('Altura Negada');
# Out:
# Altura Aceita

# %%
#7
tempAtual = -5;
tempMax = -2;
if tempAtual>tempMax:
  print('Alarme: Atenção! Temperatura Alta');
else:
  print('Alarme não dispara');
# Out:
# Alarme não dispara

# %%
#8
senhaCorreta=12345;
senhaInserida=12345;
if senhaInserida==senhaCorreta:
  print('Acesso Permitido');
else:
  print('Acesso Negado');
# Out:
# Acesso Permitido

# %%
#9
pessoLimite=800;
pessoAtual=850;
if pessoLimite>=pessoAtual:
 print('Peso Aceitavel');
else:
  print('Peso Excessivo');
# Out:
# Peso excessivo

# %%
#10
crachaGuarda=99;
turnoManha=10;
turnoNoite=99;

#Verrificação para o turno da manhã
if crachaGuarda==turnoManha:
  print('Acesso Permitido, tenha um bom dia!');
else:
  print('Acesso Negado');
# Out:
# Acesso Negado

# %%
#11.1
ingresso=True;
pulseira=False;
valor=0;

if ingresso==True:
  valor=valor+1;
if pulseira==True:
  valor=valor+2;

if valor==0:
 print('Você não possui o ingresso nem a pulseira vip para esse show.');
if valor==1:
 print('Você possui o ingresso, mas não a pulseira vip.');
if valor==2:
 print('Você possui acesso a área vip, mas não o ingresso para o show.');
if ingresso and pulseira==True:
  print('Você possui o ingresso e a pulseira vip, aproveite o show!');
# Out:
# Você possui o ingresso e a pulseira vip, aproveite o show!

# %%
#11.2
ingresso = True;
pulseira = False;


print('Seja, Bem-Vindo(a)');
if ingresso==True:
  print('Ingresso;');

if pulseira==True:
 print('Pulseira vip;');

if (ingresso and pulseira) == True:
  print('Aproveite o Show com acesso a area vip!');

else:
  if ingresso==True:
   print('Aproveite o Show sem acesso a area vip!');

  else:
    print('Você não possui o ingresso para esse show!');
# Out:
# Seja, Bem-Vindo(a)
# Ingresso;
# Aproveite o Show sem acesso a area vip!

# %%
#12
estudante=False
doadorSangue=True

if (estudante or doadorSangue):
 print('Você tem direto a meia!');
# Out:
# Você tem direto a meia!

# %%
#13
incendio=False;

if incendio==True:
 print('Porta Destravada');
else:
 print('Porta Trancada');
# Out:
# Porta Trancada

# %%
#14
motor=True;
clima=True;

if (motor and clima):
 print('Lançamento Autorizado');
else:
  print('Lançamento Negado');
# Out:
# Lançamento Autorizado

# %%
#15
pedido=False;
cartao=False;

if (pedido or cartao):
  print('Assinatura Cancelada');
else:
  print('Assinatura Continuada');
# Out:
# Assinatura Continuada

# %%
#16
nota=65;
falta=10;

if (nota>60) and (falta<15):
  print('Aprovado');
else:
  print('Reprovado');
# Out:
# Aprovado

# %%
#17
cupom=False;
quantProduts=3;
valorProduts= (40*quantProduts);

if (valorProduts>=100) or (cupom):
 print('Você ganhou frete grátis');
else:
  print('Sua compra ficou: R$', valorProduts, '+ Frete');
# Out:
# Você ganhou frete grátis

# %%
#18
num=14;
verf=num%2

if (verf==0) and (num>0):
 print('Aprovado')
else:
  print('Reprovado')
# Out:
# Aprovado

# %%
#19
bateria=15;
vento=25;

if (bateria>20) and (vento<=30):
  print('Vou liberado, divirta-se!')
else:
  print('Vou bloqueado!')
# Out:
# Vou bloqueado!

# %%
#20
cimentoRequisitado=50
valorCimento=(cimentoRequisitado*30)
#fds=Fim De Semana
fds=False

if (valorCimento<=2000) and (fds==False):
  print('Compra Aprovada no valor de', valorCimento, 'R$');
else:
  print('Compra Reporvada')
# Out:
# Compra Aprovada no valor de 1500 R$
